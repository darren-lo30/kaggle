# %%
import pandas as pd
import numpy as np
import random as rnd
import scipy

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)


train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')
combine = [train_df, test_df]
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
total = train_df.isnull().sum().sort_values(ascending=False)
percent = (train_df.isnull().sum()/train_df.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Id                0  0.000000

# %% [markdown]
# Unneeded columns:
# - LotFrontage (Area encapsulates better)
# - Electrical System

# %%
dropped_cols = ['LotFrontage', 'Electrical', 'MiscFeature', 'MSZoning']
for dataset in combine:
  dataset.drop(dropped_cols, axis=1, inplace=True)
  
train_df.head()
# Out:
#    Id  MSSubClass  LotArea Street Alley LotShape LandContour Utilities  \
# 0   1          60     8450   Pave   NaN      Reg         Lvl    AllPub
# 1   2          20     9600   Pave   NaN      Reg         Lvl    AllPub
# 2   3          60    11250   Pave   NaN      IR1         Lvl    AllPub
# 3   4          70     9550   Pave   NaN      IR1         Lvl    AllPub
# 4   5          60    14260   Pave   NaN      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %% [markdown]
# Combine porch/deck areas into one

# %%
porch_and_decks = ['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']
for dataset in combine:
  dataset['PorchArea'] = dataset[porch_and_decks].sum(axis=1).astype(int)
  dataset.drop(porch_and_decks, axis=1, inplace=True)

train_df.head()
# Out:
#    Id  MSSubClass  LotArea Street Alley LotShape LandContour Utilities  \
# 0   1          60     8450   Pave   NaN      Reg         Lvl    AllPub
# 1   2          20     9600   Pave   NaN      Reg         Lvl    AllPub
# 2   3          60    11250   Pave   NaN      IR1         Lvl    AllPub
# 3   4          70     9550   Pave   NaN      IR1         Lvl    AllPub
# 4   5          60    14260   Pave   NaN      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %% [markdown]
# Porch Area vs Sale Price

# %%
g = sns.scatterplot(train_df, y='SalePrice', x='PorchArea')

# %%
g = sns.scatterplot(train_df, y='SalePrice', x='FullBath')

# %% [markdown]
# Merge Baths

# %%
for dataset in combine:
  dataset['TotalFullBaths'] = dataset['FullBath'] + dataset['BsmtFullBath']
  dataset['TotalHalfBaths'] = dataset['HalfBath'] + dataset['BsmtHalfBath']
  dataset.drop(['FullBath', 'HalfBath', 'BsmtFullBath', 'BsmtHalfBath'], axis=1, inplace=True)

train_df.head()
# Out:
#    Id  MSSubClass  LotArea Street Alley LotShape LandContour Utilities  \
# 0   1          60     8450   Pave   NaN      Reg         Lvl    AllPub
# 1   2          20     9600   Pave   NaN      Reg         Lvl    AllPub
# 2   3          60    11250   Pave   NaN      IR1         Lvl    AllPub
# 3   4          70     9550   Pave   NaN      IR1         Lvl    AllPub
# 4   5          60    14260   Pave   NaN      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %%
train_df[['Alley', 'SalePrice']].groupby('Alley', as_index=False).mean().sort_values(by='SalePrice', ascending=False)
# Out:
#   Alley      SalePrice
# 1  Pave  168000.585366
# 0  Grvl  122219.080000

# %%
quality_mapping = {'Na': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5}
for dataset in combine:
  dataset.drop(['YrSold'], axis=1, inplace=True)
  dataset['GarageCond'] = dataset['GarageCond'].map(quality_mapping)
train_df.head()
# Out:
#    Id  MSSubClass  LotArea Street Alley LotShape LandContour Utilities  \
# 0   1          60     8450   Pave   NaN      Reg         Lvl    AllPub
# 1   2          20     9600   Pave   NaN      Reg         Lvl    AllPub
# 2   3          60    11250   Pave   NaN      IR1         Lvl    AllPub
# 3   4          70     9550   Pave   NaN      IR1         Lvl    AllPub
# 4   5          60    14260   Pave   NaN      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %% [markdown]
# Categorical Data Coorelations

# %%
categorical_features = ['Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'Heating', 'HeatingQC', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'PavedDrive', 'SaleType', 'SaleCondition', 'BsmtCond', "CentralAir", 'BsmtFinType2']
for feature in categorical_features:
  for dataset in combine:
    dataset[feature] = dataset[feature].astype('category')
  # display(train_df[[feature, 'OverallQual']].groupby(feature, as_index=False).mean().sort_values(by='OverallQual', ascending=False))

# %%
corr = train_df.corr(numeric_only  = True)

g = sns.heatmap(corr, cmap="Blues", annot=False, xticklabels=1, yticklabels=1)
g.set_xlabel('X-Axis', fontsize=2)
# Out:
# Text(0.5, 23.52222222222222, 'X-Axis')

# %% [markdown]
# High Correlations between:
# - TotRmsAbvGrd and GrLivArea
# - GrLivArea and Overall Qual
# - Overall Quial and SalePrice
# - TotalBsmntSF and 1stFlrSF

# %%
for dataset in combine:
  dataset['HasBsmt'] = (dataset['TotalBsmtSF'] != 0).astype(int)
dropped_features = [ 'Alley', 'TotalBsmtSF', 'BsmtCond', 'ExterQual', 'BsmtQual', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'PoolQC', 'Fence', 'Exterior1st', 'Exterior2nd', 'GarageType', 'GarageFinish', 'GarageYrBlt', 'GarageArea', 'GarageQual']
for dataset in combine:
  dataset.drop(dropped_features, axis=1, inplace=True)

# train_df[['OverallCond', 'SalePrice']].groupby('OverallCond', as_index=False).mean().sort_values(by='SalePrice', ascending=False)
# Drop quality and cond measurements in favour of overall cond/qual
# Drop exterior 1st and 2nd due to too many categories
train_df.head()
# Out:
#    Id  MSSubClass  LotArea Street LotShape LandContour Utilities LotConfig  \
# 0   1          60     8450   Pave      Reg         Lvl    AllPub    Inside
# 1   2          20     9600   Pave      Reg         Lvl    AllPub       FR2
# 2   3          60    11250   Pave      IR1         Lvl    AllPub    Inside
# 3   4          70     9550   Pave      IR1         Lvl    AllPub    Corner
# 4   5          60    14260   Pave      IR1         Lvl    AllPub       FR2
#
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %%
train_df[['MasVnrType', 'OverallQual']].groupby('MasVnrType', as_index=False).mean().sort_values(by='OverallQual', ascending=False)
# Out:
#   MasVnrType  OverallQual
# 3      Stone     7.578125
# 1    BrkFace     6.568539
# 2       None     5.642361
# 0     BrkCmn     5.266667

# %%
for dataset in combine:
  dataset.drop(['MasVnrType', 'MasVnrArea', 'RoofStyle', 'RoofMatl'], axis=1, inplace=True)

train_df.head()
# Out:
#    Id  MSSubClass  LotArea Street LotShape LandContour Utilities LotConfig  \
# 0   1          60     8450   Pave      Reg         Lvl    AllPub    Inside
# 1   2          20     9600   Pave      Reg         Lvl    AllPub       FR2
# 2   3          60    11250   Pave      IR1         Lvl    AllPub    Inside
# 3   4          70     9550   Pave      IR1         Lvl    AllPub    Corner
# 4   5          60    14260   Pave      IR1         Lvl    AllPub       FR2
#
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd ExterCond Foundation  \
# ...

# %%
g = sns.scatterplot(train_df, x='GrLivArea', y='SalePrice')

# %%
train_df = train_df.drop(train_df[(train_df['GrLivArea']>4000) & (train_df['SalePrice'] < 300000)].index)
combine = [train_df, test_df]

# %%
def display_norm(data):
  fig, ax =plt.subplots(1,2)
  g = sns.histplot(data, kde=True, stat='density', ax=ax[0])
  x0, x1 = g.get_xlim()
  mu, std = scipy.stats.norm.fit(data)
  x_pdf = np.linspace(x0, x1, 100)
  y_pdf = scipy.stats.norm.pdf(x_pdf, mu, std)
  g.plot(x_pdf, y_pdf, 'r')
  g.legend()

  scipy.stats.probplot(data, plot=ax[1])

display_norm(train_df['SalePrice'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_df['SalePrice'] = np.log(train_df['SalePrice'])
display_norm(train_df['SalePrice'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
display_norm(train_df['GrLivArea'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for dataset in combine:
  dataset['GrLivArea'] = np.log(dataset['GrLivArea'])
display_norm(train_df['GrLivArea'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
display_norm(train_df['1stFlrSF'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for dataset in combine:
  dataset['1stFlrSF'] = np.log(dataset['1stFlrSF'])
display_norm(train_df['1stFlrSF'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn import datasets, ensemble
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

X_train = train_df.drop(['Id', 'SalePrice'], axis=1)
Y_train = train_df['SalePrice']

xgb_tree = xgb.XGBRegressor(tree_method="gpu_hist", enable_categorical=True)
xgb_tree.fit(X_train, Y_train)

kfold = KFold(n_splits=10)
score = cross_val_score(xgb_tree, X_train, Y_train, cv=kfold).mean()
score
# Out:
# 0.8870080404225416

# %%
X_test = test_df.drop(['Id'], axis=1)
X_test.head()
Y_pred = xgb_tree.predict(X_test)
# We normlaize,d unormalize
Y_pred = np.exp(Y_pred)
submission = pd.DataFrame({
  'Id': test_df['Id'],
  'SalePrice': Y_pred,
})

submission.to_csv('./output/submission.csv', index=False)
